# %%
import pandas as pd
import pyforest
import warnings
warnings.filterwarnings("ignore")
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder

from sklearn.linear_model import LogisticRegression

# %%
car_data = 'data/car.data'
headers = ['buying','maint','doors','persons','lug_boot','safety','class']

# %%
df = pd.read_csv(car_data, names=headers)

# %% [markdown]
# ## High level exploratory data

# %%
df.head()
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
df.describe()
# Out:
#        buying maint doors persons lug_boot safety  class
# count    1728  1728  1728    1728     1728   1728   1728
# unique      4     4     4       3        3      3      4
# top       low   low     4       4    small    low  unacc
# freq      432   432   432     576      576    576   1210

# %% [markdown]
# Check distribution of records for 'buying' column to ensure no skewness of data

# %%
df.groupby('buying').count()
# Out:
#         maint  doors  persons  lug_boot  safety  class
# buying
# high      432    432      432       432     432    432
# low       432    432      432       432     432    432
# med       432    432      432       432     432    432
# vhigh     432    432      432       432     432    432

# %% [markdown]
# ## Encode categorical data to numerical values

# %%
input_oe = OrdinalEncoder()
target_oe = OrdinalEncoder()

def preprocess_input(X):
    X_enc = input_oe.fit_transform(X)
    return X_enc


def preprocess_target(y):
    y_enc = target_oe.fit_transform(y)
    return y_enc

# %%
X = df.drop(['buying'], axis=1)
y = df.buying
y = y.to_frame()

# %%
X_enc = preprocess_input(X)
y_enc = preprocess_target(y)

# %% [markdown]
# ## Split into train and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_enc, y_enc, 
                                                    test_size=0.2, 
                                                    stratify=y_enc)

# %%
# Check on final shapes of training and test sets
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1382, 6)
# (1382, 1)
# (346, 6)
# (346, 1)

# %% [markdown]
# ## Fit logistic regression model

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Make predictions

# %%
new_input = {
    'maint':'high',
    'doors':'4',
    'persons':'',
    'lug_boot':'big',
    'safety':'high',
    'class':'good'
}
df_new = pd.DataFrame(new_input, index =[0])
df_new
# Out:
#   maint doors persons lug_boot safety class
# 0  high     4              big   high  good

# %%
df_new_enc = preprocess_input(df_new)

# %%
results = model.predict(df_new_enc)
print('Before reshape: ', results.shape)

results = results.reshape(1,1)
print('After reshape: ', results.shape)
# Out:
# Before reshape:  (1,)
# After reshape:  (1, 1)

# %%
r = target_oe.inverse_transform(results)
print('Buying price prediction = ', r[0][0])
# Out:
# Buying price prediction =  high

# %% [markdown]
# ___

# %% [markdown]
# ##### Trying other models

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True)
models, predictions = clf.fit(X_train, 
                              X_test,
                              y_train, 
                              y_test)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 18.03it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 0.30               0.30    None      0.29
# Perceptron                         0.29               0.29    None      0.23
# GaussianNB                         0.29               0.29    None      0.21
# CalibratedClassifierCV             0.29               0.29    None      0.27
# SGDClassifier                      0.27               0.27    None      0.21
# BernoulliNB                        0.26               0.26    None      0.18
# LogisticRegression                 0.25               0.25    None      0.23
# DummyClassifier                    0.25               0.25    None      0.25
# RidgeClassifierCV                  0.25               0.25    None      0.23
# RidgeClassifier                    0.25               0.25    None      0.23
# LinearSVC                          0.25               0.25    None      0.23
# LinearDiscriminantAnalysis         0.25               0.25    None      0.23
# NearestCentroid                    0.25               0.25    None      0.22
# PassiveAggressiveClassifier        0.24               0.24    None      0.22
# QuadraticDiscriminantAnalysis      0.24               0.24    None      0.22
# SVC                                0.23               0.23    None      0.22
# KNeighborsClassifier               0.14               0.14    None      0.14
# NuSVC                              0.12               0.12    None      0.11
# LGBMClassifier                     0.10               0.10    None      0.10
# BaggingClassifier                  0.08               0.08    None      0.08
# XGBClassifier                      0.08               0.08    None      0.08
# RandomForestClassifier             0.08               0.08    None      0.08
# LabelSpreading                     0.08               0.08    None      0.08
# ExtraTreesClassifier               0.08               0.08    None      0.09
# DecisionTreeClassifier             0.08               0.07    None      0.08
# LabelPropagation                   0.08               0.07    None      0.07
# ExtraTreeClassifier                0.07               0.07    None      0.07
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.07
# Perceptron                           0.01
# GaussianNB                           0.01
# CalibratedClassifierCV               0.22
# SGDClassifier                        0.04
# BernoulliNB                          0.01
# LogisticRegression                   0.01
# DummyClassifier                      0.01
# RidgeClassifierCV                    0.01
# RidgeClassifier                      0.01
# LinearSVC                            0.05
# LinearDiscriminantAnalysis           0.01
# NearestCentroid                      0.01
# PassiveAggressiveClassifier          0.01
# QuadraticDiscriminantAnalysis        0.01
# SVC                                  0.05
# KNeighborsClassifier                 0.01
# NuSVC                                0.19
# LGBMClassifier                       0.22
# BaggingClassifier                    0.02
# XGBClassifier                        0.26
# RandomForestClassifier               0.14
# LabelSpreading                       0.05
# ExtraTreesClassifier                 0.12
# DecisionTreeClassifier               0.01
# LabelPropagation                     0.04
# ExtraTreeClassifier                  0.01
